# %% [markdown]
# # Example Notebook
#
# This notebook is a minimal example for the open-source release.
# Set API_BASE_URL and token in the cell below if needed.

# %%
import os
import requests

API_BASE_URL = os.getenv("API_BASE_URL", "http://127.0.0.1:54321")
TOKEN = os.getenv("BACKTEST_TOKEN", "")

print("API_BASE_URL=", API_BASE_URL)
print("TOKEN set?", bool(TOKEN))

# %%
2 ** 10
